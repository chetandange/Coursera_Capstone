# %% [markdown]
# ### In this notebook we are going to do the Capstone project of the Data science Course, in this we are going to use various APIs to and various data science and Machine learning techniques to find the best place for us for living.

# %%
import pandas as pd
import numpy as np

# %%
print('Hello Capstone Project Course!')
# Out:
# Hello Capstone Project Course!
